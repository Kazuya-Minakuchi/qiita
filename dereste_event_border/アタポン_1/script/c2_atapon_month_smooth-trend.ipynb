# %% [markdown]
# # アタポン
# * アタポンの1位データに絞る
# * ちょうど毎月開催されてるので、月次にしてみる
#   * 「月の中で何日に開催された」とかは一旦考慮しない
# * 平滑化トレンドモデルにしてみる

# %% [markdown]
# ## インポート

# %%
import numpy as np
import pandas as pd
import pickle
import datetime
from datetime import timedelta
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font=['IPAMincho'])

import pystan

# %% [markdown]
# ## イベントデータ読み込み

# %%
input_dir = '../../common/event_data/'

# %%
df = pd.read_pickle(input_dir + 'a3_output_df.pkl')
df = df[df['形式'] == 'アタポン'].set_index('日付')
df
# Out:
#                               イベント       1位   2001位    形式   属性     期間
# 日付
# 2015-09-25           アタシポンコツアンドロイド   427777   78330  アタポン  NaN  249.0
# 2015-10-19             Nation Blue   324369   67627  アタポン  NaN  198.0
# 2015-11-20         Orange Sapphire   350000   42944  アタポン  NaN  150.0
# 2015-12-18              Snow Wings   520000   50954  アタポン  NaN  222.0
# 2016-01-20               パステルピンクな恋   602529   43854  アタポン  NaN  174.0
# 2016-02-18                オルゴールの小箱   523819   56737  アタポン  NaN  174.0
# 2016-03-20             絶対特権主張しますっ！   530000   51353  アタポン  NaN  174.0
# 2016-04-19                     つぼみ   666666   47907  アタポン  NaN  174.0
# 2016-05-19               明日また会えるよね   844167   58517  アタポン  NaN  198.0
# 2016-06-20                咲いてJewel   650152   77930  アタポン  NaN  174.0
# 2016-07-19                きみにいっぱい☆   615000   50759  アタポン  NaN  198.0
# 2016-08-19             Near to You   760307   46355  アタポン  NaN  198.0
# 2016-09-20                   ラブレター   596000  121303  アタポン  NaN  150.0
# 2016-10-20       Jet to the Future   609969   69430  アタポン  NaN  174.0
# 2016-11-19               Flip Flop   700000   64568  アタポン  NaN  198.0
# 2016-12-21               あんきら!?狂騒曲   694253   91619  アタポン  NaN  150.0
# 2017-01-20            Lunatic Show   684784  103834  アタポン  NaN  174.0
# 2017-02-17            情熱ファンファンファーレ   881000   87731  アタポン  NaN  198.0
# 2017-03-21                  ∀NSWER   715889   77131  アタポン  NaN  174.0
# 2017-04-19                Nocturne   711125   64224  アタポン  NaN  174.0
# 2017-05-19           モーレツ★世直しギルティ！   917400   85036  アタポン  NaN  222.0
# 2017-06-19       Yes！ Party Time！！   721149  102781  アタポン  NaN  174.0
# 2017-07-20     Kawaii make MY day！   775836   70863  アタポン  NaN  174.0
# 2017-08-21                  双翼の独奏歌   709450  156206  アタポン  NaN  150.0
# 2017-09-20            Twin☆くるっ★テール   807041  114084  アタポン  NaN  174.0
# 2017-10-20          Halloween♥Code   844167   89011  アタポン  NaN  174.0
# 2017-11-19           Trinity Field   783042  193847  アタポン  NaN  174.0
# 2017-12-20                 冬空プレシャス   765000   63299  アタポン  NaN  174.0
# 2018-01-12                美に入り彩を穿つ   748760  112616  アタポン  NaN  150.0
# 2018-02-19                   Frost   679865   93945  アタポン  NaN  150.0
# 2018-03-20              キラッ！満開スマイル   932639  144198  アタポン  NaN  198.0
# 2018-04-19        Spring Screaming   825782   67629  アタポン  NaN  174.0
# 2018-05-21              HARURUNRUN   751205   58907  アタポン  NaN  174.0
# 2018-06-19              エチュードは1曲だけ   817257   86964  アタポン  NaN  174.0
# 2018-07-19              SUN♡FLOWER   942493   74511  アタポン  NaN  198.0
# 2018-08-19              クレイジークレイジー   925686  163641  アタポン  NaN  198.0
# 2018-09-19             Pretty Liar   954312  224697  アタポン  NaN  198.0
# 2018-10-19            アンデッド・ダンスロック   974760   83532  アタポン  NaN  198.0
# 2018-11-19        Sunshine See May   945614  156519  アタポン  NaN  198.0
# 2018-12-19                Trust me   978776   78278  アタポン  NaN  198.0
# 2019-01-21               スパイスパラダイス   883242  179632  アタポン  NaN  174.0
# 2019-02-19            Needle Light   730000   67182  アタポン  NaN  150.0
# 2019-03-20                  未完成の歴史   886578  143192  アタポン  NaN  174.0
# 2019-04-19            きゅん・きゅん・まっくす   870742   73887  アタポン  NaN  174.0
# 2019-05-21                Max Beat   910638   68476  アタポン  NaN  174.0
# 2019-06-21  TAKAMARI☆CLIMAXXX！！！！！   936000   72590  アタポン  NaN  198.0
# 2019-07-22                    バベル   1059763  151703  アタポン  NaN  157.0
# 2019-08-20            comic cosmic  1129958   82849  アタポン  NaN  174.0
# 2019-09-20               ステップ＆スキップ  1161870  147582  アタポン  NaN  174.0
# 2019-10-21                  空想探査計画  1100000   71393  アタポン  NaN  174.0
# 2019-11-20         Secret Daybreak  1180231  169639  アタポン  NaN  175.0
# 2019-12-20           ギュっとMilky Way  1111111   99081  アタポン  NaN  174.0
# 2020-01-20             幸せの法則 ～ルール～  1268425  115890  アタポン  NaN  198.0
# 2020-02-18                      印象  1424681   76797  アタポン  NaN  198.0
# 2020-03-21            輝け！ビートシューター   1330000   84545  アタポン  NaN  198.0
# 2020-04-20               Athanasia  1130000   75775  アタポン  NaN  174.0
# 2020-05-19               不埒なCANVAS  1271125  188652  アタポン  NaN  198.0
# 2020-06-19      Sing the Prologue♪  1123140   85574  アタポン  NaN  174.0
# 2020-07-20                 太陽の絵の具箱  1120703  107142  アタポン  NaN  174.0
# 2020-08-19        ヒーローヴァーサスレイナンジョー  1250000   60211  アタポン  NaN  174.0

# %%
# プロットしてみる
fig = plt.figure()
ax = fig.add_subplot(111)
x = df.index
y = df.loc[:, '1位']
ax.plot(x, y)
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['IPAMincho'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ## stanデータ準備

# %%
# データ（辞書型）
dat = {
    'T':       len(df),         # 全日付の日数
    'y':       df['1位'].tolist(), # 観測値
}

# %%
# Stanコード
model = """
data {
  int T;                   // データ取得期間の長さ
  vector[T] y;       // 観測値
}
parameters {
  vector[T] mu;
  real<lower=0> s_w;
  real<lower=0> s_v;
}
model {
  for(i in 3:T){
    mu[i] ~ normal(2*mu[i-1] - mu[i-2], s_w);
    y[i] ~ normal(mu[i], s_v);
  }
}
"""

# %% [markdown]
# ## Stan実行

# %%
# コンパイル
# %time stm = pystan.StanModel(model_code=model)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_3740aced05cf22d96ac4408a74567f91 NOW.
# C:\Users\kazuy\Anaconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\kazuy\AppData\Local\Temp\tmp25enxkgx\stanfit4anon_model_3740aced05cf22d96ac4408a74567f91_5666137917383208459.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Wall time: 23.6 s

# %%
# パラメータ設定
n_itr = 5000
n_warmup = n_itr - 1000
chains = 3

# %%
# 計算
# %time fit = stm.sampling(data=dat, iter=n_itr, chains=chains, n_jobs=-1, warmup=n_warmup, algorithm="NUTS", verbose=False)
# Out:
# Wall time: 23 s

# %%
# ファイル保存
save_dir = '../event_data/'
with open(save_dir + 'c2_model.pickle', mode="wb") as f:
    pickle.dump(stm, f)
with open(save_dir + 'c2_fit.pickle', mode="wb") as f:
    pickle.dump(fit, f)
# Out:
# C:\Users\kazuy\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Pickling fit objects is an experimental feature!
# The relevant StanModel instance must be pickled along with this fit object.
# When unpickling the StanModel must be unpickled first.

# %% [markdown]
# ### 結果確認

# %%
fit
# Out:
# Inference for Stan model: anon_model_3740aced05cf22d96ac4408a74567f91.
# 3 chains, each with iter=5000; warmup=4000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=3000.
#
#          mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# mu[0]   3.5e5  7024.9  1.1e5  1.1e5  2.9e5  3.6e5  4.3e5  5.4e5    241   1.01
# mu[1]   4.0e5  6478.1  8.2e4  2.2e5  3.5e5  4.0e5  4.5e5  5.4e5    162   1.02
# mu[2]   4.4e5  6225.5  6.1e4  3.2e5  4.0e5  4.4e5  4.8e5  5.6e5     96   1.02
# mu[3]   4.9e5  4936.6  4.7e4  4.0e5  4.6e5  4.9e5  5.2e5  5.9e5     90   1.02
# mu[4]   5.3e5  3832.9  4.0e4  4.6e5  5.1e5  5.3e5  5.6e5  6.2e5    107   1.02
# mu[5]   5.7e5  2408.5  3.6e4  5.0e5  5.5e5  5.7e5  5.9e5  6.4e5    229   1.02
# mu[6]   6.0e5  1946.5  3.5e4  5.4e5  5.8e5  6.0e5  6.3e5  6.7e5    329   1.01
# mu[7]   6.3e5  1859.5  3.6e4  5.7e5  6.1e5  6.3e5  6.6e5  7.0e5    370   1.01
# mu[8]   6.6e5  1878.7  3.6e4  5.9e5  6.3e5  6.6e5  6.8e5  7.3e5    367   1.01
# mu[9]   6.7e5  1556.4  3.4e4  6.0e5  6.4e5  6.7e5  6.9e5  7.4e5    474   1.01
# mu[10]  6.7e5  1177.5  3.2e4  6.1e5  6.5e5  6.7e5  6.9e5  7.4e5    753    1.0
# mu[11]  6.8e5  847.91  3.2e4  6.2e5  6.6e5  6.8e5  7.0e5  7.4e5   1431    1.0
# mu[12]  6.8e5  1236.5  3.3e4  6.1e5  6.6e5  6.8e5  7.0e5  7.4e5    711    1.0
# mu[13]  6.9e5  1353.7  3.3e4  6.2e5  6.7e5  6.9e5  7.1e5  7.5e5    594    1.0
# mu[14]  7.0e5  1238.9  3.2e4  6.3e5  6.8e5  7.0e5  7.2e5  7.6e5    684    1.0
# mu[15]  7.1e5  921.06  3.1e4  6.5e5  6.9e5  7.1e5  7.3e5  7.7e5   1163    1.0
# mu[16]  7.3e5  1050.1  3.1e4  6.6e5  7.1e5  7.3e5  7.5e5  7.9e5    867    1.0
# mu[17]  7.5e5  1429.8  3.2e4  6.8e5  7.3e5  7.4e5  7.7e5  8.1e5    487   1.01
# mu[18]  7.6e5  1592.4  3.2e4  7.0e5  7.4e5  7.6e5  7.8e5  8.2e5    404   1.01
# mu[19]  7.7e5  1386.2  3.2e4  7.0e5  7.5e5  7.7e5  7.9e5  8.3e5    547   1.01
# mu[20]  7.7e5  1341.0  3.3e4  7.1e5  7.5e5  7.7e5  8.0e5  8.4e5    598   1.01
# mu[21]  7.8e5  1338.1  3.2e4  7.1e5  7.5e5  7.8e5  8.0e5  8.4e5    587   1.01
# mu[22]  7.8e5  1411.5  3.3e4  7.1e5  7.6e5  7.8e5  8.0e5  8.4e5    536   1.01
# mu[23]  7.8e5  1625.9  3.3e4  7.2e5  7.6e5  7.8e5  8.0e5  8.5e5    424   1.01
# mu[24]  7.8e5  1722.0  3.4e4  7.2e5  7.6e5  7.8e5  8.0e5  8.6e5    401   1.01
# mu[25]  7.8e5  1866.7  3.5e4  7.2e5  7.6e5  7.8e5  8.1e5  8.6e5    347   1.01
# mu[26]  7.8e5  1829.0  3.5e4  7.2e5  7.6e5  7.8e5  8.1e5  8.6e5    357   1.01
# mu[27]  7.8e5  1882.5  3.4e4  7.2e5  7.6e5  7.8e5  8.0e5  8.6e5    325   1.01
# mu[28]  7.9e5  1880.2  3.4e4  7.2e5  7.6e5  7.9e5  8.1e5  8.6e5    324   1.02
# mu[29]  8.0e5  2017.1  3.4e4  7.3e5  7.7e5  7.9e5  8.2e5  8.6e5    277   1.02
# mu[30]  8.1e5  2234.4  3.4e4  7.4e5  7.9e5  8.1e5  8.3e5  8.7e5    227   1.02
# mu[31]  8.2e5  2466.9  3.4e4  7.6e5  8.0e5  8.2e5  8.5e5  8.9e5    192   1.02
# mu[32]  8.4e5  2663.8  3.5e4  7.6e5  8.2e5  8.4e5  8.6e5  9.1e5    173   1.02
# mu[33]  8.6e5  3154.3  3.6e4  7.7e5  8.4e5  8.6e5  8.8e5  9.3e5    132   1.02
# mu[34]  8.8e5  4241.8  3.9e4  7.8e5  8.6e5  8.8e5  9.0e5  9.5e5     83   1.03
# mu[35]  9.0e5  4844.4  4.1e4  7.9e5  8.7e5  8.9e5  9.2e5  9.7e5     72   1.03
# mu[36]  9.1e5  4876.4  4.2e4  8.0e5  8.8e5  9.0e5  9.3e5  9.8e5     73   1.03
# mu[37]  9.1e5  3929.3  4.0e4  8.2e5  8.9e5  9.1e5  9.4e5  9.9e5    105   1.03
# mu[38]  9.1e5  3041.1  3.7e4  8.4e5  8.9e5  9.1e5  9.3e5  9.9e5    149   1.02
# mu[39]  9.0e5  1849.8  3.4e4  8.4e5  8.8e5  9.0e5  9.2e5  9.7e5    330   1.01
# mu[40]  9.0e5  1267.8  3.3e4  8.3e5  8.7e5  9.0e5  9.2e5  9.6e5    684    1.0
# mu[41]  8.9e5  1769.2  3.6e4  8.2e5  8.7e5  8.9e5  9.2e5  9.6e5    419   1.01
# mu[42]  9.0e5  2142.2  3.9e4  8.2e5  8.8e5  9.0e5  9.3e5  9.7e5    325   1.01
# mu[43]  9.2e5  2203.1  3.9e4  8.4e5  9.0e5  9.2e5  9.5e5  9.9e5    318   1.01
# mu[44]  9.5e5  1918.9  3.8e4  8.7e5  9.2e5  9.5e5  9.7e5  1.0e6    383   1.01
# mu[45]  9.9e5  1347.2  3.5e4  9.1e5  9.6e5  9.9e5  1.0e6  1.1e6    683    1.0
# mu[46]  1.0e6  1042.7  3.4e4  9.6e5  1.0e6  1.0e6  1.0e6  1.1e6   1041    1.0
# mu[47]  1.1e6  1128.3  3.3e4  1.0e6  1.0e6  1.1e6  1.1e6  1.1e6    866    1.0
# mu[48]  1.1e6  1272.6  3.3e4  1.0e6  1.1e6  1.1e6  1.1e6  1.2e6    679   1.01
# mu[49]  1.1e6  1362.1  3.4e4  1.1e6  1.1e6  1.1e6  1.2e6  1.2e6    612   1.01
# mu[50]  1.2e6  1493.1  3.4e4  1.1e6  1.2e6  1.2e6  1.2e6  1.2e6    526   1.01
# mu[51]  1.2e6  1770.5  3.5e4  1.1e6  1.2e6  1.2e6  1.2e6  1.3e6    397   1.01
# mu[52]  1.2e6  2118.6  3.7e4  1.2e6  1.2e6  1.2e6  1.3e6  1.3e6    306   1.01
# mu[53]  1.2e6  2230.3  3.8e4  1.2e6  1.2e6  1.2e6  1.3e6  1.3e6    293   1.01
# mu[54]  1.2e6  1721.6  3.6e4  1.2e6  1.2e6  1.2e6  1.3e6  1.3e6    431    1.0
# mu[55]  1.2e6  997.28  3.3e4  1.2e6  1.2e6  1.2e6  1.3e6  1.3e6   1091    1.0
# mu[56]  1.2e6  1112.1  3.3e4  1.2e6  1.2e6  1.2e6  1.2e6  1.3e6    894   1.01
# mu[57]  1.2e6  1632.2  3.7e4  1.1e6  1.2e6  1.2e6  1.2e6  1.3e6    510   1.01
# mu[58]  1.2e6  2174.2  4.4e4  1.1e6  1.2e6  1.2e6  1.2e6  1.3e6    401   1.01
# mu[59]  1.2e6  2624.6  5.7e4  1.1e6  1.2e6  1.2e6  1.2e6  1.3e6    468   1.01
# s_w     1.5e4  773.92 6965.2 6666.6  1.0e4  1.4e4  1.9e4  3.3e4     81   1.03
# s_v     8.5e4   496.9 9660.8  6.8e4  7.8e4  8.4e4  9.1e4  1.0e5    378    1.0
# lp__    -1247    3.19  21.85  -1289  -1263  -1248  -1231  -1208     47   1.05
#
# Samples were drawn using NUTS at Tue Nov 10 07:38:45 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
fit.plot()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['IPAMincho'] not found. Falling back to DejaVu Sans.

# %%
#結果を抽出
ms = fit.extract() 

#muの事後平均を算出
mu_mean = ms['mu'].mean(axis=0)

#95パーセンタイルを抽出
mu_5 = np.array(pd.DataFrame(ms['mu']).apply(lambda x: np.percentile(x, 5), axis=0))
mu_95 = np.array(pd.DataFrame(ms['mu']).apply(lambda x: np.percentile(x, 95), axis=0))

#x軸
X = df.index

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(X, df['1位'], label='observed')
# ax.plot(X, mu, label='true trend', c='green')
ax.plot(X, mu_mean, label='predicted trend', c='red')
plt.fill_between(X, mu_5, mu_95, color='red', alpha=0.2)
# plt.legend(loc='upper left', borderaxespad=0, fontsize=15)
plt.show()

# %% [markdown]
# ローカルレベルモデルよりはスムーズにつなぎにいくため、過去のデータでは外れるものが多くなっている
