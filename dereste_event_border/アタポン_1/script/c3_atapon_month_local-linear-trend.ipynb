# %% [markdown]
# # アタポン
# * アタポンの1位データに絞る
# * ちょうど毎月開催されてるので、月次にしてみる
#   * 「月の中で何日に開催された」とかは一旦考慮しない
# * ローカル線形トレンドモデルにしてみる

# %% [markdown]
# ## インポート

# %%
import numpy as np
import pandas as pd
import pickle
import datetime
from datetime import timedelta
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font=['IPAMincho'])

import pystan

# %% [markdown]
# ## イベントデータ読み込み

# %%
input_dir = '../../common/event_data/'

# %%
df = pd.read_pickle(input_dir + 'a3_output_df.pkl')
df = df[df['形式'] == 'アタポン'].set_index('日付')
df
# Out:
#                               イベント       1位   2001位    形式   属性     期間
# 日付
# 2015-09-25           アタシポンコツアンドロイド   427777   78330  アタポン  NaN  249.0
# 2015-10-19             Nation Blue   324369   67627  アタポン  NaN  198.0
# 2015-11-20         Orange Sapphire   350000   42944  アタポン  NaN  150.0
# 2015-12-18              Snow Wings   520000   50954  アタポン  NaN  222.0
# 2016-01-20               パステルピンクな恋   602529   43854  アタポン  NaN  174.0
# 2016-02-18                オルゴールの小箱   523819   56737  アタポン  NaN  174.0
# 2016-03-20             絶対特権主張しますっ！   530000   51353  アタポン  NaN  174.0
# 2016-04-19                     つぼみ   666666   47907  アタポン  NaN  174.0
# 2016-05-19               明日また会えるよね   844167   58517  アタポン  NaN  198.0
# 2016-06-20                咲いてJewel   650152   77930  アタポン  NaN  174.0
# 2016-07-19                きみにいっぱい☆   615000   50759  アタポン  NaN  198.0
# 2016-08-19             Near to You   760307   46355  アタポン  NaN  198.0
# 2016-09-20                   ラブレター   596000  121303  アタポン  NaN  150.0
# 2016-10-20       Jet to the Future   609969   69430  アタポン  NaN  174.0
# 2016-11-19               Flip Flop   700000   64568  アタポン  NaN  198.0
# 2016-12-21               あんきら!?狂騒曲   694253   91619  アタポン  NaN  150.0
# 2017-01-20            Lunatic Show   684784  103834  アタポン  NaN  174.0
# 2017-02-17            情熱ファンファンファーレ   881000   87731  アタポン  NaN  198.0
# 2017-03-21                  ∀NSWER   715889   77131  アタポン  NaN  174.0
# 2017-04-19                Nocturne   711125   64224  アタポン  NaN  174.0
# 2017-05-19           モーレツ★世直しギルティ！   917400   85036  アタポン  NaN  222.0
# 2017-06-19       Yes！ Party Time！！   721149  102781  アタポン  NaN  174.0
# 2017-07-20     Kawaii make MY day！   775836   70863  アタポン  NaN  174.0
# 2017-08-21                  双翼の独奏歌   709450  156206  アタポン  NaN  150.0
# 2017-09-20            Twin☆くるっ★テール   807041  114084  アタポン  NaN  174.0
# 2017-10-20          Halloween♥Code   844167   89011  アタポン  NaN  174.0
# 2017-11-19           Trinity Field   783042  193847  アタポン  NaN  174.0
# 2017-12-20                 冬空プレシャス   765000   63299  アタポン  NaN  174.0
# 2018-01-12                美に入り彩を穿つ   748760  112616  アタポン  NaN  150.0
# 2018-02-19                   Frost   679865   93945  アタポン  NaN  150.0
# 2018-03-20              キラッ！満開スマイル   932639  144198  アタポン  NaN  198.0
# 2018-04-19        Spring Screaming   825782   67629  アタポン  NaN  174.0
# 2018-05-21              HARURUNRUN   751205   58907  アタポン  NaN  174.0
# 2018-06-19              エチュードは1曲だけ   817257   86964  アタポン  NaN  174.0
# 2018-07-19              SUN♡FLOWER   942493   74511  アタポン  NaN  198.0
# 2018-08-19              クレイジークレイジー   925686  163641  アタポン  NaN  198.0
# 2018-09-19             Pretty Liar   954312  224697  アタポン  NaN  198.0
# 2018-10-19            アンデッド・ダンスロック   974760   83532  アタポン  NaN  198.0
# 2018-11-19        Sunshine See May   945614  156519  アタポン  NaN  198.0
# 2018-12-19                Trust me   978776   78278  アタポン  NaN  198.0
# 2019-01-21               スパイスパラダイス   883242  179632  アタポン  NaN  174.0
# 2019-02-19            Needle Light   730000   67182  アタポン  NaN  150.0
# 2019-03-20                  未完成の歴史   886578  143192  アタポン  NaN  174.0
# 2019-04-19            きゅん・きゅん・まっくす   870742   73887  アタポン  NaN  174.0
# 2019-05-21                Max Beat   910638   68476  アタポン  NaN  174.0
# 2019-06-21  TAKAMARI☆CLIMAXXX！！！！！   936000   72590  アタポン  NaN  198.0
# 2019-07-22                    バベル   1059763  151703  アタポン  NaN  157.0
# 2019-08-20            comic cosmic  1129958   82849  アタポン  NaN  174.0
# 2019-09-20               ステップ＆スキップ  1161870  147582  アタポン  NaN  174.0
# 2019-10-21                  空想探査計画  1100000   71393  アタポン  NaN  174.0
# 2019-11-20         Secret Daybreak  1180231  169639  アタポン  NaN  175.0
# 2019-12-20           ギュっとMilky Way  1111111   99081  アタポン  NaN  174.0
# 2020-01-20             幸せの法則 ～ルール～  1268425  115890  アタポン  NaN  198.0
# 2020-02-18                      印象  1424681   76797  アタポン  NaN  198.0
# 2020-03-21            輝け！ビートシューター   1330000   84545  アタポン  NaN  198.0
# 2020-04-20               Athanasia  1130000   75775  アタポン  NaN  174.0
# 2020-05-19               不埒なCANVAS  1271125  188652  アタポン  NaN  198.0
# 2020-06-19      Sing the Prologue♪  1123140   85574  アタポン  NaN  174.0
# 2020-07-20                 太陽の絵の具箱  1120703  107142  アタポン  NaN  174.0
# 2020-08-19        ヒーローヴァーサスレイナンジョー  1250000   60211  アタポン  NaN  174.0

# %%
# プロットしてみる
fig = plt.figure()
ax = fig.add_subplot(111)
x = df.index
y = df.loc[:, '1位']
ax.plot(x, y)
plt.show()

# %% [markdown]
# ## stanデータ準備

# %%
# データ（辞書型）
dat = {
    'T':       len(df),         # 全日付の日数
    'y':       df['1位'].tolist(), # 観測値
}

# %%
# Stanコード
model = """
data {
  int T;                   // データ取得期間の長さ
  vector[T] y;       // 観測値
}
parameters {
  vector[T] mu;      // 水準+ドリフト成分の推定値
  vector[T] delta;   // ドリフト成分の推定値
  real<lower=0> s_w; // 水準成分の変動の大きさを表す標準偏差
  real<lower=0> s_z; // ドリフト成分の変動の大きさを表す標準偏差
  real<lower=0> s_v; // 観測誤差の標準偏差
}
model {
  for(i in 2:T){
    mu[i] ~ normal(mu[i-1] + delta[i-1], s_w);
    delta[i] ~ normal(delta[i-1], s_z);
    y[i] ~ normal(mu[i], s_v);
  }
}
"""

# %% [markdown]
# ## Stan実行

# %%
# コンパイル
# %time stm = pystan.StanModel(model_code=model)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_6756962f483cdcec6d2c866a76ea3170 NOW.
# C:\Users\kazuy\Anaconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\kazuy\AppData\Local\Temp\tmpyxg76ybv\stanfit4anon_model_6756962f483cdcec6d2c866a76ea3170_8800275699308654674.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Wall time: 23.2 s

# %%
# パラメータ設定
n_itr = 4000
n_warmup = n_itr - 1000
chains = 3

# %%
# 計算
# %time fit = stm.sampling(data=dat, iter=n_itr, chains=chains, n_jobs=-1, warmup=n_warmup, algorithm="NUTS", verbose=False)
# Out:
# Wall time: 32.1 s

# %%
# ファイル保存
save_dir = '../event_data/'
with open(save_dir + 'c3_model.pickle', mode="wb") as f:
    pickle.dump(stm, f)
with open(save_dir + '
4  1.1e6  1.2e6  1.2e6  1.2e6  1.3e6    640   1.01
# mu[52]     1.2e6  1854.6  4.5e4  1.2e6  1.2e6  1.2e6  1.3e6  1.3e6    584    1.0
# mu[53]     1.3e6  5077.6  6.0e4  1.2e6  1.3e6  1.3e6  1.3e6  1.4e6    139   1.03
# mu[54]     1.3e6  2060.0  4.8e4  1.2e6  1.2e6  1.3e6  1.3e6  1.4e6    536   1.01
# mu[55]     1.2e6  1510.8  4.3e4  1.1e6  1.2e6  1.2e6  1.2e6  1.3e6    827   1.01
# mu[56]     1.2e6   745.9  4.1e4  1.1e6  1.2e6  1.2e6  1.2e6  1.3e6   3000    1.0
# mu[57]     1.2e6  2384.6  4.7e4  1.1e6  1.1e6  1.2e6  1.2e6  1.3e6    394   1.01
# mu[58]     1.2e6  1962.6  5.0e4  1.1e6  1.1e6  1.2e6  1.2e6  1.3e6    646   1.01
# mu[59]     1.2e6  978.37  5.4e4  1.1e6  1.2e6  1.2e6  1.3e6  1.3e6   3000   1.01
# delta[0]   2.9e4  2332.2  2.5e4 -1.1e4  1.4e4  2.6e4  4.1e4  9.1e4    115   1.03
# delta[1]   3.0e4  2402.8  2.3e4  -8973  1.4e4  2.6e4  4.2e4  8.5e4     95   1.04
# delta[2]   3.0e4  2479.8  2.2e4  -6417  1.5e4  2.6e4  4.1e4  8.2e4     81   1.04
# delta[3]   2.8e4  2157.6  2.1e4  -6449  1.5e4  2.6e4  3.9e4  7.7e4     92   1.04
# delta[4]   2.6e4  1731.5  1.8e4  -5639  1.5e4  2.5e4  3.7e4  6.6e4    110   1.03
# delta[5]   2.5e4  1522.9  1.7e4  -4566  1.4e4  2.4e4  3.5e4  6.3e4    125   1.02
# delta[6]   2.4e4  1384.0  1.6e4  -4343  1.3e4  2.3e4  3.3e4  6.0e4    140   1.02
# delta[7]   2.2e4  813.99  1.6e4  -7058  1.2e4  2.1e4  3.0e4  5.7e4    376   1.01
# delta[8]   1.8e4  732.08  1.6e4 -1.4e4 9217.2  1.8e4  2.7e4  5.0e4    458   1.01
# delta[9]   1.6e4  1136.8  1.6e4 -1.8e4 7765.6  1.6e4  2.5e4  4.8e4    187   1.02
# delta[10]  1.5e4  842.62  1.5e4 -2.0e4 7360.3  1.5e4  2.4e4  4.5e4    335   1.02
# delta[11]  1.4e4  1185.2  1.6e4 -2.1e4 6160.5  1.5e4  2.3e4  4.3e4    172   1.02
# delta[12]  1.4e4  998.53  1.5e4 -1.8e4 6405.9  1.5e4  2.3e4  4.4e4    237   1.01
# delta[13]  1.5e4  671.43  1.5e4 -1.6e4 7032.8  1.5e4  2.4e4  4.6e4    496   1.01
# delta[14]  1.5e4  674.79  1.5e4 -1.3e4 7166.0  1.5e4  2.4e4  4.6e4    484   1.01
# delta[15]  1.5e4  694.77  1.5e4 -1.4e4 6867.2  1.5e4  2.3e4  4.6e4    474   1.01
# delta[16]  1.5e4  697.63  1.5e4 -1.4e4 6880.5  1.5e4  2.3e4  4.7e4    471   1.01
# delta[17]  1.4e4  709.69  1.5e4 -1.8e4 5842.3  1.4e4  2.2e4  4.4e4    443   1.01
# delta[18]  1.3e4  734.59  1.5e4 -1.9e4 5102.3  1.3e4  2.1e4  4.2e4    405   1.02
# delta[19]  1.3e4  792.87  1.5e4 -2.0e4 4465.1  1.3e4  2.1e4  4.4e4    366   1.02
# delta[20]  1.1e4  1369.3  1.5e4 -2.1e4 3022.5  1.1e4  2.0e4  4.1e4    125   1.03
# delta[21]  1.1e4  1411.1  1.5e4 -2.1e4 2791.6  1.1e4  2.0e4  4.2e4    120   1.03
# delta[22]  1.1e4  1359.9  1.5e4 -2.3e4 2501.9  1.1e4  1.9e4  4.3e4    125   1.03
# delta[23]  1.1e4  1145.2  1.5e4 -2.1e4 2913.8  1.1e4  1.9e4  4.3e4    178   1.03
# delta[24]  1.1e4  1156.3  1.5e4 -2.4e4 2709.9  1.1e4  1.9e4  4.2e4    171   1.03
# delta[25] 9988.7  1258.7  1.6e4 -2.7e4 2060.0  1.1e4  1.9e4  4.1e4    159   1.03
# delta[26]  1.0e4  1296.1  1.6e4 -2.6e4 2088.0  1.1e4  1.9e4  4.1e4    148   1.03
# delta[27]  1.1e4  1246.6  1.6e4 -2.6e4 2797.3  1.1e4  1.9e4  4.2e4    159   1.03
# delta[28]  1.2e4  909.29  1.5e4 -2.3e4 3826.1  1.2e4  2.0e4  4.3e4    283   1.02
# delta[29]  1.3e4  717.42  1.5e4 -1.8e4 4899.6  1.3e4  2.1e4  4.6e4    459   1.01
# delta[30]  1.3e4   702.5  1.5e4 -1.7e4 5566.9  1.3e4  2.1e4  4.6e4    480   1.01
# delta[31]  1.4e4  715.65  1.5e4 -1.8e4 5650.3  1.4e4  2.2e4  4.6e4    466   1.01
# delta[32]  1.5e4  767.91  1.6e4 -1.5e4 6243.4  1.4e4  2.3e4  4.8e4    409   1.01
# delta[33]  1.5e4  812.12  1.6e4 -1.5e4 6478.7  1.4e4  2.3e4  5.1e4    371   1.01
# delta[34]  1.5e4   746.4  1.5e4 -1.4e4 5532.3  1.4e4  2.3e4  4.8e4    424    1.0
# delta[35]  1.3e4  727.44  1.5e4 -1.6e4 4622.8  1.3e4  2.1e4  4.6e4    433   1.01
# delta[36]  1.2e4  779.63  1.6e4 -2.0e4 3628.3  1.2e4  2.0e4  4.5e4    404   1.01
# delta[37]  1.1e4  1209.5  1.6e4 -2.6e4 2224.6  1.1e4  1.9e4  4.2e4    180   1.03
# delta[38] 9651.1  1466.4  1.7e4 -3.1e4 1232.8  1.1e4  1.9e4  4.1e4    132   1.04
# delta[39] 9143.7  1769.7  1.7e4 -3.1e4 908.73  1.1e4  1.9e4  4.0e4     95   1.05
# delta[40]  1.1e4  1438.6  1.7e4 -2.8e4 2176.8  1.2e4  2.0e4  4.1e4    135   1.03
# delta[41]  1.4e4  621.71  1.6e4 -1.9e4 5171.5  1.4e4  2.2e4  4.6e4    647    1.0
# delta[42]  1.6e4  642.19  1.5e4 -1.3e4 7198.6  1.5e4  2.4e4  4.9e4    575    1.0
# delta[43]  1.8e4  874.69  1.6e4 -1.1e4 9110.7  1.7e4  2.6e4  5.3e4    327   1.02
# delta[44]  2.0e4  1387.5  1.7e4  -9127 9671.2  1.9e4  2.9e4  5.9e4    149   1.03
# delta[45]  2.1e4  1589.7  1.7e4  -8253  1.1e4  1.9e4  3.0e4  6.3e4    120   1.04
# delta[46]  2.1e4  1491.4  1.7e4  -8677  1.1e4  2.0e4  3.0e4  6.0e4    131   1.04
# delta[47]  2.1e4  1281.9  1.7e4  -8007  1.0e4  1.9e4  3.0e4  5.7e4    167   1.03
# delta[48]  2.0e4  937.91  1.7e4 -1.1e4 9584.0  1.8e4  2.9e4  5.4e4    312   1.02
# delta[49]  1.9e4  914.17  1.6e4  -9177 8838.7  1.8e4  2.8e4  5.5e4    318   1.02
# delta[50]  1.8e4  913.42  1.6e4 -1.0e4 8431.1  1.7e4  2.8e4  5.4e4    309   1.02
# delta[51]  1.7e4  837.29  1.6e4 -1.0e4 8011.0  1.6e4  2.6e4  5.1e4    356   1.01
# delta[52]  1.5e4  678.24  1.5e4 -1.5e4 5842.0  1.4e4  2.4e4  4.7e4    519    1.0
# delta[53]  1.2e4  861.81  1.6e4 -2.3e4 2830.3  1.2e4  2.1e4  4.1e4    335   1.02
# delta[54] 8702.9  1740.7  1.8e4 -3.5e4 -85.64  1.0e4  2.0e4  4.1e4    107   1.04
# delta[55] 8311.3  2455.4  1.8e4 -3.2e4  -1195 9640.7  2.0e4  4.1e4     54   1.05
# delta[56] 7991.3  2576.8  1.9e4 -3.7e4  -1359 9504.4  2.0e4  4.3e4     55   1.04
# delta[57] 8693.5  2377.6  2.0e4 -3.8e4  -1049 9969.8  2.1e4  4.5e4     68   1.03
# delta[58] 9724.8  1390.2  2.1e4 -3.7e4 -906.8  1.0e4  2.2e4  4.9e4    229   1.02
# delta[59] 9561.2  1734.3  2.3e4 -4.5e4  -1222  1.1e4  2.3e4  5.3e4    182   1.02
# s_w        5.3e4  4163.4  2.2e4 8100.5  3.9e4  5.3e4  6.8e4  9.9e4     29    1.1
# s_z       7321.1  1721.4 6667.2 656.53 2545.2 5235.6 9871.1  2.6e4     15   1.19
# s_v        7.0e4  1298.3  1.4e4  4.0e4  6.2e4  7.1e4  8.0e4  9.7e4    119   1.03
# lp__       -1850   13.03  52.12  -1950  -1888  -1847  -1812  -1750     16   1.18
#
# Samples were drawn using NUTS at Tue Nov 10 07:42:12 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
fit.plot()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['IPAMincho'] not found. Falling back to DejaVu Sans.

# %%
#結果を抽出
ms = fit.extract() 

#muの事後平均を算出
mu_mean = ms['mu'].mean(axis=0)

#95パーセンタイルを抽出
mu_5 = np.array(pd.DataFrame(ms['mu']).apply(lambda x: np.percentile(x, 5), axis=0))
mu_95 = np.array(pd.DataFrame(ms['mu']).apply(lambda x: np.percentile(x, 95), axis=0))

# delta
# 事後平均
delta_mean = ms['delta'].mean(axis=0)
# #95パーセンタイル抽出
delta_5 = np.array(pd.DataFrame(ms['delta']).apply(lambda x: np.percentile(x, 5), axis=0))
delta_95 = np.array(pd.DataFrame(ms['delta']).apply(lambda x: np.percentile(x, 95), axis=0))

#x軸
X = df.index

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(X, df['1位'], label='observed')
# ax.plot(X, mu, label='true trend', c='green')
ax.plot(X, mu_mean, label='predicted trend', c='red')
plt.fill_between(X, mu_5, mu_95, color='red', alpha=0.2)
# plt.legend(loc='upper left', borderaxespad=0, fontsize=15)
plt.show()

# %%
# delta
fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(X, delta_mean, label='predicted trend', c='red')
plt.fill_between(X, delta_5, delta_95, color='red', alpha=0.2)
plt.show()

# %% [markdown]
# * やはり、平滑化トレンドの滑らかさとローカルトレンドのガタガタの中間くらいになってる
# * トレンドの変化は以下のようなものによると考えられるので、実際はローカル線形トレンドモデルが一番良く表せると思われる
#   * プレイヤーの数の変化（滑らかな変化）
#   * キャラの性能の変化（滑らかな変化）
#   * グランドライブなど、新機能の実装（急な変化）
