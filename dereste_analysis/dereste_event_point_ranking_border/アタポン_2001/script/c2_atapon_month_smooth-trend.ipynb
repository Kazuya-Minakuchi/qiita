# %% [markdown]
# # アタポン
# * アタポンの2001位データに絞る
# * ちょうど毎月開催されてるので、月次にしてみる
#   * 「月の中で何日に開催された」とかは一旦考慮しない
# * 平滑化トレンドモデルにしてみる

# %% [markdown]
# ## インポート

# %%
import numpy as np
import pandas as pd
import pickle
import datetime
from datetime import timedelta
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font=['IPAMincho'])

import pystan

# %% [markdown]
# ## イベントデータ読み込み

# %%
input_dir = '../../common/event_data/'

# %%
df = pd.read_pickle(input_dir + 'a3_output_df.pkl')
df = df[df['形式'] == 'アタポン'].set_index('日付')
df
# Out:
#                               イベント       1位   2001位    形式   属性     期間
# 日付
# 2015-09-25           アタシポンコツアンドロイド   427777   78330  アタポン  NaN  249.0
# 2015-10-19             Nation Blue   324369   67627  アタポン  NaN  198.0
# 2015-11-20         Orange Sapphire   350000   42944  アタポン  NaN  150.0
# 2015-12-18              Snow Wings   520000   50954  アタポン  NaN  222.0
# 2016-01-20               パステルピンクな恋   602529   43854  アタポン  NaN  174.0
# 2016-02-18                オルゴールの小箱   523819   56737  アタポン  NaN  174.0
# 2016-03-20             絶対特権主張しますっ！   530000   51353  アタポン  NaN  174.0
# 2016-04-19                     つぼみ   666666   47907  アタポン  NaN  174.0
# 2016-05-19               明日また会えるよね   844167   58517  アタポン  NaN  198.0
# 2016-06-20                咲いてJewel   650152   77930  アタポン  NaN  174.0
# 2016-07-19                きみにいっぱい☆   615000   50759  アタポン  NaN  198.0
# 2016-08-19             Near to You   760307   46355  アタポン  NaN  198.0
# 2016-09-20                   ラブレター   596000  121303  アタポン  NaN  150.0
# 2016-10-20       Jet to the Future   609969   69430  アタポン  NaN  174.0
# 2016-11-19               Flip Flop   700000   64568  アタポン  NaN  198.0
# 2016-12-21               あんきら!?狂騒曲   694253   91619  アタポン  NaN  150.0
# 2017-01-20            Lunatic Show   684784  103834  アタポン  NaN  174.0
# 2017-02-17            情熱ファンファンファーレ   881000   87731  アタポン  NaN  198.0
# 2017-03-21                  ∀NSWER   715889   77131  アタポン  NaN  174.0
# 2017-04-19                Nocturne   711125   64224  アタポン  NaN  174.0
# 2017-05-19           モーレツ★世直しギルティ！   917400   85036  アタポン  NaN  222.0
# 2017-06-19       Yes！ Party Time！！   721149  102781  アタポン  NaN  174.0
# 2017-07-20     Kawaii make MY day！   775836   70863  アタポン  NaN  174.0
# 2017-08-21                  双翼の独奏歌   709450  156206  アタポン  NaN  150.0
# 2017-09-20            Twin☆くるっ★テール   807041  114084  アタポン  NaN  174.0
# 2017-10-20          Halloween♥Code   844167   89011  アタポン  NaN  174.0
# 2017-11-19           Trinity Field   783042  193847  アタポン  NaN  174.0
# 2017-12-20                 冬空プレシャス   765000   63299  アタポン  NaN  174.0
# 2018-01-12                美に入り彩を穿つ   748760  112616  アタポン  NaN  150.0
# 2018-02-19                   Frost   679865   93945  アタポン  NaN  150.0
# 2018-03-20              キラッ！満開スマイル   932639  144198  アタポン  NaN  198.0
# 2018-04-19        Spring Screaming   825782   67629  アタポン  NaN  174.0
# 2018-05-21              HARURUNRUN   751205   58907  アタポン  NaN  174.0
# 2018-06-19              エチュードは1曲だけ   817257   86964  アタポン  NaN  174.0
# 2018-07-19              SUN♡FLOWER   942493   74511  アタポン  NaN  198.0
# 2018-08-19              クレイジークレイジー   925686  163641  アタポン  NaN  198.0
# 2018-09-19             Pretty Liar   954312  224697  アタポン  NaN  198.0
# 2018-10-19            アンデッド・ダンスロック   974760   83532  アタポン  NaN  198.0
# 2018-11-19        Sunshine See May   945614  156519  アタポン  NaN  198.0
# 2018-12-19                Trust me   978776   78278  アタポン  NaN  198.0
# 2019-01-21               スパイスパラダイス   883242  179632  アタポン  NaN  174.0
# 2019-02-19            Needle Light   730000   67182  アタポン  NaN  150.0
# 2019-03-20                  未完成の歴史   886578  143192  アタポン  NaN  174.0
# 2019-04-19            きゅん・きゅん・まっくす   870742   73887  アタポン  NaN  174.0
# 2019-05-21                Max Beat   910638   68476  アタポン  NaN  174.0
# 2019-06-21  TAKAMARI☆CLIMAXXX！！！！！   936000   72590  アタポン  NaN  198.0
# 2019-07-22                    バベル   1059763  151703  アタポン  NaN  157.0
# 2019-08-20            comic cosmic  1129958   82849  アタポン  NaN  174.0
# 2019-09-20               ステップ＆スキップ  1161870  147582  アタポン  NaN  174.0
# 2019-10-21                  空想探査計画  1100000   71393  アタポン  NaN  174.0
# 2019-11-20         Secret Daybreak  1180231  169639  アタポン  NaN  175.0
# 2019-12-20           ギュっとMilky Way  1111111   99081  アタポン  NaN  174.0
# 2020-01-20             幸せの法則 ～ルール～  1268425  115890  アタポン  NaN  198.0
# 2020-02-18                      印象  1424681   76797  アタポン  NaN  198.0
# 2020-03-21            輝け！ビートシューター   1330000   84545  アタポン  NaN  198.0
# 2020-04-20               Athanasia  1130000   75775  アタポン  NaN  174.0
# 2020-05-19               不埒なCANVAS  1271125  188652  アタポン  NaN  198.0
# 2020-06-19      Sing the Prologue♪  1123140   85574  アタポン  NaN  174.0
# 2020-07-20                 太陽の絵の具箱  1120703  107142  アタポン  NaN  174.0
# 2020-08-19        ヒーローヴァーサスレイナンジョー  1250000   60211  アタポン  NaN  174.0

# %%
# プロットしてみる
fig = plt.figure()
ax = fig.add_subplot(111)
x = df.index
y = df.loc[:, '2001位']
ax.plot(x, y)
plt.show()

# %% [markdown]
# ## stanデータ準備

# %%
# データ（辞書型）
dat = {
    'T':       len(df),         # 全日付の日数
    'y':       df['2001位'].tolist(), # 観測値
}

# %%
# Stanコード
model = """
data {
  int T;                   // データ取得期間の長さ
  vector[T] y;       // 観測値
}
parameters {
  vector[T] mu;
  real<lower=0> s_w;
  real<lower=0> s_v;
}
model {
  for(i in 3:T){
    mu[i] ~ normal(2*mu[i-1] - mu[i-2], s_w);
    y[i] ~ normal(mu[i], s_v);
  }
}
"""

# %% [markdown]
# ## Stan実行

# %%
# コンパイル
# %time stm = pystan.StanModel(model_code=model)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_3740aced05cf22d96ac4408a74567f91 NOW.
# C:\Users\kazuy\Anaconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\kazuy\AppData\Local\Temp\tmpcl9e0p8o\stanfit4anon_model_3740aced05cf22d96ac4408a74567f91_3089312793106247698.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Wall time: 23.2 s

# %%
# パラメータ設定
n_itr = 5000
n_warmup = n_itr - 1000
chains = 3

# %%
# 計算
# %time fit = stm.sampling(data=dat, iter=n_itr, chains=chains, n_jobs=-1, warmup=n_warmup, algorithm="NUTS", verbose=False)
# Out:
# Wall time: 38.6 s

# %%
# ファイル保存
save_dir = '../event_data/'
with open(save_dir + 'c2_model.pickle', mode="wb") as f:
    pickle.dump(stm, f)
with open(save_dir + 'c2_fit.pickle', mode="wb") as f:
    pickle.dump(fit, f)
# Out:
# C:\Users\kazuy\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Pickling fit objects is an experimental feature!
# The relevant StanModel instance must be pickled along with this fit object.
# When unpickling the StanModel must be unpickled first.

# %% [markdown]
# ### 結果確認

# %%
fit
# Out:
# Inference for Stan model: anon_model_3740aced05cf22d96ac4408a74567f91.
# 3 chains, each with iter=5000; warmup=4000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=3000.
#
#          mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# mu[0]   3.9e4  1018.0  2.3e4  -7049  2.4e4  4.0e4  5.4e4  8.3e4    516   1.01
# mu[1]   4.2e4   944.2  2.0e4 2354.9  2.9e4  4.3e4  5.6e4  8.1e4    466   1.01
# mu[2]   4.5e4  879.78  1.8e4 9484.4  3.3e4  4.6e4  5.7e4  7.9e4    419   1.02
# mu[3]   4.8e4  823.42  1.6e4  1.7e4  3.7e4  4.9e4  5.9e4  7.8e4    376   1.02
# mu[4]   5.1e4  780.02  1.4e4  2.3e4  4.1e4  5.1e4  6.1e4  7.9e4    337   1.02
# mu[5]   5.4e4  730.53  1.3e4  2.9e4  4.5e4  5.4e4  6.3e4  7.9e4    317   1.02
# mu[6]   5.7e4  690.32  1.2e4  3.4e4  4.9e4  5.7e4  6.6e4  8.0e4    302   1.03
# mu[7]   6.0e4  654.33  1.1e4  3.8e4  5.2e4  6.0e4  6.8e4  8.2e4    294   1.02
# mu[8]   6.3e4  619.39  1.1e4  4.2e4  5.6e4  6.3e4  7.0e4  8.4e4    292   1.02
# mu[9]   6.6e4  591.28  1.0e4  4.6e4  5.9e4  6.6e4  7.3e4  8.6e4    294   1.02
# mu[10]  6.9e4  567.06 9805.4  5.0e4  6.2e4  6.9e4  7.6e4  8.7e4    299   1.02
# mu[11]  7.2e4  563.01 9620.6  5.3e4  6.5e4  7.1e4  7.8e4  9.0e4    292   1.01
# mu[12]  7.5e4  555.64 9494.7  5.6e4  6.8e4  7.4e4  8.1e4  9.2e4    292   1.01
# mu[13]  7.7e4  556.35 9457.8  5.9e4  7.1e4  7.7e4  8.4e4  9.5e4    289   1.01
# mu[14]  8.0e4   567.2 9422.9  6.1e4  7.4e4  8.0e4  8.6e4  9.9e4    276    1.0
# mu[15]  8.3e4   608.9 9393.6  6.4e4  7.6e4  8.3e4  8.9e4  1.0e5    238    1.0
# mu[16]  8.5e4  630.36 9392.2  6.7e4  7.9e4  8.5e4  9.2e4  1.0e5    222    1.0
# mu[17]  8.8e4  657.91 9396.7  7.0e4  8.1e4  8.8e4  9.4e4  1.1e5    204    1.0
# mu[18]  9.0e4  680.34 9402.4  7.2e4  8.4e4  9.0e4  9.6e4  1.1e5    191    1.0
# mu[19]  9.2e4  699.57 9463.6  7.4e4  8.6e4  9.2e4  9.9e4  1.1e5    183   1.01
# mu[20]  9.5e4  716.71 9535.2  7.6e4  8.8e4  9.4e4  1.0e5  1.1e5    177   1.01
# mu[21]  9.7e4  729.72 9680.8  7.9e4  9.0e4  9.7e4  1.0e5  1.2e5    176   1.01
# mu[22]  9.9e4  768.06 9805.9  8.1e4  9.2e4  9.9e4  1.1e5  1.2e5    163   1.02
# mu[23]  1.0e5  783.62 9912.0  8.3e4  9.4e4  1.0e5  1.1e5  1.2e5    160   1.02
# mu[24]  1.0e5  790.69 9907.3  8.5e4  9.6e4  1.0e5  1.1e5  1.2e5    157   1.02
# mu[25]  1.0e5  803.58 9907.1  8.7e4  9.8e4  1.0e5  1.1e5  1.2e5    152   1.03
# mu[26]  1.1e5  800.83 9873.2  8.8e4  9.9e4  1.1e5  1.1e5  1.3e5    152   1.03
# mu[27]  1.1e5  788.18 9844.4  8.9e4  1.0e5  1.1e5  1.1e5  1.3e5    156   1.03
# mu[28]  1.1e5  776.37 9851.0  9.0e4  1.0e5  1.1e5  1.1e5  1.3e5    161   1.03
# mu[29]  1.1e5  735.36 9838.4  9.1e4  1.0e5  1.1e5  1.2e5  1.3e5    179   1.03
# mu[30]  1.1e5  720.09 9847.1  9.1e4  1.0e5  1.1e5  1.2e5  1.3e5    187   1.03
# mu[31]  1.1e5  706.34 9863.4  9.2e4  1.0e5  1.1e5  1.2e5  1.3e5    195   1.03
# mu[32]  1.1e5  693.02 9874.0  9.3e4  1.1e5  1.1e5  1.2e5  1.3e5    203   1.03
# mu[33]  1.1e5  686.37 9898.9  9.4e4  1.1e5  1.1e5  1.2e5  1.3e5    208   1.03
# mu[34]  1.1e5  684.82 9994.5  9.5e4  1.1e5  1.1e5  1.2e5  1.3e5    213   1.03
# mu[35]  1.1e5  688.92  1.0e4  9.5e4  1.1e5  1.1e5  1.2e5  1.3e5    214   1.03
# mu[36]  1.1e5   686.9  1.0e4  9.6e4  1.1e5  1.1e5  1.2e5  1.3e5    218   1.03
# mu[37]  1.2e5  674.05  1.0e4  9.6e4  1.1e5  1.1e5  1.2e5  1.3e5    229   1.03
# mu[38]  1.2e5  650.77  1.0e4  9.6e4  1.1e5  1.1e5  1.2e5  1.4e5    248   1.02
# mu[39]  1.1e5  626.95  1.0e4  9.6e4  1.1e5  1.1e5  1.2e5  1.4e5    266   1.02
# mu[40]  1.1e5  596.37  1.0e4  9.6e4  1.1e5  1.1e5  1.2e5  1.3e5    289   1.02
# mu[41]  1.1e5  573.73  1.0e4  9.5e4  1.1e5  1.1e5  1.2e5  1.3e5    305   1.01
# mu[42]  1.1e5  550.05 9931.5  9.4e4  1.1e5  1.1e5  1.2e5  1.3e5    326   1.01
# mu[43]  1.1e5  525.45 9816.1  9.3e4  1.1e5  1.1e5  1.2e5  1.3e5    349   1.01
# mu[44]  1.1e5  511.39 9676.0  9.3e4  1.1e5  1.1e5  1.2e5  1.3e5    358    1.0
# mu[45]  1.1e5  499.83 9536.2  9.2e4  1.1e5  1.1e5  1.2e5  1.3e5    364    1.0
# mu[46]  1.1e5  484.99 9429.2  9.2e4  1.0e5  1.1e5  1.2e5  1.3e5    378    1.0
# mu[47]  1.1e5  463.86 9369.5  9.2e4  1.0e5  1.1e5  1.2e5  1.3e5    408    1.0
# mu[48]  1.1e5  436.47 9371.3  9.1e4  1.0e5  1.1e5  1.2e5  1.3e5    461    1.0
# mu[49]  1.1e5  424.13 9407.6  9.0e4  1.0e5  1.1e5  1.2e5  1.3e5    492    1.0
# mu[50]  1.1e5  402.25 9459.2  8.9e4  1.0e5  1.1e5  1.2e5  1.3e5    553    1.0
# mu[51]  1.1e5  396.57 9608.1  8.8e4  1.0e5  1.1e5  1.1e5  1.3e5    587    1.0
# mu[52]  1.1e5  397.74 9839.4  8.6e4  1.0e5  1.1e5  1.1e5  1.3e5    612    1.0
# mu[53]  1.1e5  412.92  1.0e4  8.5e4  1.0e5  1.1e5  1.1e5  1.3e5    618    1.0
# mu[54]  1.1e5  438.44  1.1e4  8.2e4  9.9e4  1.1e5  1.1e5  1.3e5    618    1.0
# mu[55]  1.0e5  469.82  1.2e4  8.0e4  9.7e4  1.0e5  1.1e5  1.3e5    625   1.01
# mu[56]  1.0e5  504.51  1.3e4  7.7e4  9.5e4  1.0e5  1.1e5  1.3e5    646    1.0
# mu[57]  1.0e5  547.38  1.4e4  7.3e4  9.3e4  1.0e5  1.1e5  1.3e5    671    1.0
# mu[58]  1.0e5  598.87  1.6e4  6.8e4  9.1e4  1.0e5  1.1e5  1.3e5    705    1.0
# mu[59] 10.0e4  640.35  1.8e4  6.1e4  8.8e4  1.0e5  1.1e5  1.3e5    790    1.0
# s_w    1115.9   191.2 740.53 196.15 634.77 897.27 1399.2 3079.6     15   1.18
# s_v     3.9e4   96.15 3933.9  3.3e4  3.7e4  3.9e4  4.2e4  4.8e4   1674   1.01
# lp__    -1048     9.9  37.03  -1117  -1072  -1047  -1027 -962.4     14   1.25
#
# Samples were drawn using NUTS at Mon Nov  2 04:44:21 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
fit.plot()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['IPAMincho'] not found. Falling back to DejaVu Sans.

# %%
#結果を抽出
ms = fit.extract() 

#muの事後平均を算出
mu_mean = ms['mu'].mean(axis=0)

#95パーセンタイルを抽出
mu_5 = np.array(pd.DataFrame(ms['mu']).apply(lambda x: np.percentile(x, 5), axis=0))
mu_95 = np.array(pd.DataFrame(ms['mu']).apply(lambda x: np.percentile(x, 95), axis=0))

#x軸
X = df.index

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(X, df['2001位'], label='observed')
# ax.plot(X, mu, label='true trend', c='green')
ax.plot(X, mu_mean, label='predicted trend', c='red')
plt.fill_between(X, mu_5, mu_95, color='red', alpha=0.2)
# plt.legend(loc='upper left', borderaxespad=0, fontsize=15)
plt.show()

# %% [markdown]
# こちらも全然当たっていないが、ローカルレベルモデルよりはスムーズになってる
