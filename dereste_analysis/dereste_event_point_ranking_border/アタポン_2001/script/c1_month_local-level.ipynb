# %% [markdown]
# # 概要
#
# * アタポンの2001位データの予測モデル
# * ちょうど毎月開催されてるので、月次にしてみる
#   * 「月の中で何日に開催された」とかは一旦考慮しない
# * とりあえずpystan動かしてみる
#   * 試しにローカルレベルモデルで動かす

# %% [markdown]
# # インポート

# %%
import numpy as np
import pandas as pd
import pickle
import datetime
from datetime import timedelta
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font=['IPAMincho'])

import pystan

# %% [markdown]
# # イベントデータ読み込み

# %%
input_dir = '../../common/event_data/'

# %%
df = pd.read_pickle(input_dir + 'a3_output_df.pkl')
df = df[df['形式'] == 'アタポン'].set_index('日付')
df
# Out:
#                               イベント       1位   2001位    形式   属性     期間
# 日付
# 2015-09-25           アタシポンコツアンドロイド   427777   78330  アタポン  NaN  249.0
# 2015-10-19             Nation Blue   324369   67627  アタポン  NaN  198.0
# 2015-11-20         Orange Sapphire   350000   42944  アタポン  NaN  150.0
# 2015-12-18              Snow Wings   520000   50954  アタポン  NaN  222.0
# 2016-01-20               パステルピンクな恋   602529   43854  アタポン  NaN  174.0
# 2016-02-18                オルゴールの小箱   523819   56737  アタポン  NaN  174.0
# 2016-03-20             絶対特権主張しますっ！   530000   51353  アタポン  NaN  174.0
# 2016-04-19                     つぼみ   666666   47907  アタポン  NaN  174.0
# 2016-05-19               明日また会えるよね   844167   58517  アタポン  NaN  198.0
# 2016-06-20                咲いてJewel   650152   77930  アタポン  NaN  174.0
# 2016-07-19                きみにいっぱい☆   615000   50759  アタポン  NaN  198.0
# 2016-08-19             Near to You   760307   46355  アタポン  NaN  198.0
# 2016-09-20                   ラブレター   596000  121303  アタポン  NaN  150.0
# 2016-10-20       Jet to the Future   609969   69430  アタポン  NaN  174.0
# 2016-11-19               Flip Flop   700000   64568  アタポン  NaN  198.0
# 2016-12-21               あんきら!?狂騒曲   694253   91619  アタポン  NaN  150.0
# 2017-01-20            Lunatic Show   684784  103834  アタポン  NaN  174.0
# 2017-02-17            情熱ファンファンファーレ   881000   87731  アタポン  NaN  198.0
# 2017-03-21                  ∀NSWER   715889   77131  アタポン  NaN  174.0
# 2017-04-19                Nocturne   711125   64224  アタポン  NaN  174.0
# 2017-05-19           モーレツ★世直しギルティ！   917400   85036  アタポン  NaN  222.0
# 2017-06-19       Yes！ Party Time！！   721149  102781  アタポン  NaN  174.0
# 2017-07-20     Kawaii make MY day！   775836   70863  アタポン  NaN  174.0
# 2017-08-21                  双翼の独奏歌   709450  156206  アタポン  NaN  150.0
# 2017-09-20            Twin☆くるっ★テール   807041  114084  アタポン  NaN  174.0
# 2017-10-20          Halloween♥Code   844167   89011  アタポン  NaN  174.0
# 2017-11-19           Trinity Field   783042  193847  アタポン  NaN  174.0
# 2017-12-20                 冬空プレシャス   765000   63299  アタポン  NaN  174.0
# 2018-01-12                美に入り彩を穿つ   748760  112616  アタポン  NaN  150.0
# 2018-02-19                   Frost   679865   93945  アタポン  NaN  150.0
# 2018-03-20              キラッ！満開スマイル   932639  144198  アタポン  NaN  198.0
# 2018-04-19        Spring Screaming   825782   67629  アタポン  NaN  174.0
# 2018-05-21              HARURUNRUN   751205   58907  アタポン  NaN  174.0
# 2018-06-19              エチュードは1曲だけ   817257   86964  アタポン  NaN  174.0
# 2018-07-19              SUN♡FLOWER   942493   74511  アタポン  NaN  198.0
# 2018-08-19              クレイジークレイジー   925686  163641  アタポン  NaN  198.0
# 2018-09-19             Pretty Liar   954312  224697  アタポン  NaN  198.0
# 2018-10-19            アンデッド・ダンスロック   974760   83532  アタポン  NaN  198.0
# 2018-11-19        Sunshine See May   945614  156519  アタポン  NaN  198.0
# 2018-12-19                Trust me   978776   78278  アタポン  NaN  198.0
# 2019-01-21               スパイスパラダイス   883242  179632  アタポン  NaN  174.0
# 2019-02-19            Needle Light   730000   67182  アタポン  NaN  150.0
# 2019-03-20                  未完成の歴史   886578  143192  アタポン  NaN  174.0
# 2019-04-19            きゅん・きゅん・まっくす   870742   73887  アタポン  NaN  174.0
# 2019-05-21                Max Beat   910638   68476  アタポン  NaN  174.0
# 2019-06-21  TAKAMARI☆CLIMAXXX！！！！！   936000   72590  アタポン  NaN  198.0
# 2019-07-22                    バベル   1059763  151703  アタポン  NaN  157.0
# 2019-08-20            comic cosmic  1129958   82849  アタポン  NaN  174.0
# 2019-09-20               ステップ＆スキップ  1161870  147582  アタポン  NaN  174.0
# 2019-10-21                  空想探査計画  1100000   71393  アタポン  NaN  174.0
# 2019-11-20         Secret Daybreak  1180231  169639  アタポン  NaN  175.0
# 2019-12-20           ギュっとMilky Way  1111111   99081  アタポン  NaN  174.0
# 2020-01-20             幸せの法則 ～ルール～  1268425  115890  アタポン  NaN  198.0
# 2020-02-18                      印象  1424681   76797  アタポン  NaN  198.0
# 2020-03-21            輝け！ビートシューター   1330000   84545  アタポン  NaN  198.0
# 2020-04-20               Athanasia  1130000   75775  アタポン  NaN  174.0
# 2020-05-19               不埒なCANVAS  1271125  188652  アタポン  NaN  198.0
# 2020-06-19      Sing the Prologue♪  1123140   85574  アタポン  NaN  174.0
# 2020-07-20                 太陽の絵の具箱  1120703  107142  アタポン  NaN  174.0
# 2020-08-19        ヒーローヴァーサスレイナンジョー  1250000   60211  アタポン  NaN  174.0

# %%
# プロットしてみる
fig = plt.figure()
ax = fig.add_subplot(111)
x = df.index
y = df.loc[:, '2001位']
ax.plot(x, y)
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['IPAMincho'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# # stanデータ準備

# %%
# データ（辞書型）
dat = {
    'T':       len(df),         # 全日付の日数
    'y':       df['2001位'].tolist(), # 観測値
}

# %%
# Stanコード
model = """
data {
  int T;                   // データ取得期間の長さ
  vector[T] y;       // 観測値
}
parameters {
  vector[T] mu;
  real<lower=0> s_w;
  real<lower=0> s_v;
}
model {
  for(i in 2:T){
    mu[i] ~ normal(mu[i-1], s_w);
    y[i] ~ normal(mu[i], s_v);
  }
}
"""

# %% [markdown]
# # Stan実行

# %%
# コンパイル
# %time stm = pystan.StanModel(model_code=model)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9cc615073c76f7ff6f48a585e7177de5 NOW.
# C:\Users\kazuy\Anaconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\kazuy\AppData\Local\Temp\tmp48lz906i\stanfit4anon_model_9cc615073c76f7ff6f48a585e7177de5_6642460010976861577.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Wall time: 23 s

# %%
# パラメータ設定
n_itr = 5000
n_warmup = n_itr - 1000
chains = 3

# %%
# 計算
# %time fit = stm.sampling(data=dat, iter=n_itr, chains=chains, n_jobs=-1, warmup=n_warmup, algorithm="NUTS", verbose=False)
# Out:
# Wall time: 6.4 s

# %%
# ファイル保存
save_dir = '../event_data/'
with open(save_dir + 'c1_model.pickle', mode="wb") as f:
    pickle.dump(stm, f)
with open(save_dir + 'c1_fit.pickle', mode="wb") as f:
    pickle.dump(fit, f)
# Out:
# C:\Users\kazuy\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Pickling fit objects is an experimental feature!
# The relevant StanModel instance must be pickled along with this fit object.
# When unpickling the StanModel must be unpickled first.

# %% [markdown]
# # 結果確認

# %%
# 読み込み
input_dir = '../event_data/'
with open(input_dir + 'c1_model.pickle', mode="rb") as f:
    stm = pickle.load(f)
with open(input_dir + 'c1_fit.pickle', mode="rb") as f:
    fit = pickle.load(f)

# %%
fit
# Out:
# Inference for Stan model: anon_model_9cc615073c76f7ff6f48a585e7177de5.
# 3 chains, each with iter=5000; warmup=4000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=3000.
#
#          mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# mu[0]   6.1e4   445.3  1.9e4  1.9e4  4.9e4  6.1e4  7.4e4  9.5e4   1886    1.0
# mu[1]   6.0e4  567.32  1.7e4  2.5e4  4.9e4  6.1e4  7.3e4  9.1e4    919    1.0
# mu[2]   6.0e4  578.29  1.6e4  2.7e4  5.0e4  6.0e4  7.1e4  8.9e4    754    1.0
# mu[3]   6.0e4  534.62  1.5e4  3.0e4  5.1e4  6.1e4  7.0e4  8.8e4    742    1.0
# mu[4]   6.1e4  519.46  1.4e4  3.1e4  5.2e4  6.1e4  7.1e4  8.7e4    757    1.0
# mu[5]   6.2e4  533.65  1.4e4  3.2e4  5.3e4  6.2e4  7.1e4  8.7e4    704    1.0
# mu[6]   6.3e4  552.64  1.4e4  3.4e4  5.4e4  6.3e4  7.2e4  8.8e4    625    1.0
# mu[7]   6.4e4  520.79  1.4e4  3.5e4  5.5e4  6.5e4  7.4e4  8.8e4    684    1.0
# mu[8]   6.6e4   467.8  1.3e4  3.8e4  5.8e4  6.7e4  7.5e4  9.0e4    809    1.0
# mu[9]   6.8e4  433.68  1.3e4  4.1e4  6.0e4  6.9e4  7.7e4  9.3e4    894    1.0
# mu[10]  7.0e4  398.75  1.3e4  4.4e4  6.2e4  7.0e4  7.9e4  9.5e4   1019    1.0
# mu[11]  7.3e4  298.77  1.2e4  4.6e4  6.5e4  7.3e4  8.1e4  9.7e4   1726    1.0
# mu[12]  7.6e4  268.55  1.2e4  5.3e4  6.9e4  7.7e4  8.5e4  1.0e5   2118    1.0
# mu[13]  7.8e4  265.07  1.2e4  5.3e4  7.0e4  7.8e4  8.6e4  1.0e5   2154    1.0
# mu[14]  8.0e4  259.01  1.2e4  5.6e4  7.2e4  8.0e4  8.8e4  1.0e5   2214    1.0
# mu[15]  8.2e4  258.62  1.2e4  5.8e4  7.5e4  8.2e4  9.0e4  1.1e5   2150    1.0
# mu[16]  8.4e4   254.5  1.2e4  6.1e4  7.7e4  8.4e4  9.2e4  1.1e5   2197    1.0
# mu[17]  8.6e4  258.73  1.2e4  6.2e4  7.8e4  8.6e4  9.4e4  1.1e5   2184    1.0
# mu[18]  8.7e4  259.79  1.2e4  6.4e4  7.9e4  8.7e4  9.5e4  1.1e5   2132    1.0
# mu[19]  8.9e4  256.35  1.2e4  6.5e4  8.1e4  8.9e4  9.6e4  1.1e5   2169    1.0
# mu[20]  9.1e4  254.01  1.2e4  6.8e4  8.3e4  9.1e4  9.9e4  1.1e5   2175    1.0
# mu[46]  1.1e5  258.78  1.2e4  8.3e4 10.0e4  1.1e5  1.2e5  1.3e5   2186    1.0
# mu[47]  1.1e5  261.99  1.2e4  8.4e4  9.9e4  1.1e5  1.2e5  1.3e5   2118    1.0
# mu[48]  1.1e5  267.49  1.2e4  8.4e4  1.0e5  1.1e5  1.2e5  1.3e5   2119    1.0
# mu[49]  1.1e5  264.25  1.2e4  8.4e4 10.0e4  1.1e5  1.2e5  1.3e5   2172    1.0
# mu[50]  1.1e5  271.13  1.2e4  8.6e4  1.0e5  1.1e5  1.2e5  1.3e5   2100    1.0
# mu[51]  1.1e5  263.75  1.2e4  8.3e4  9.9e4  1.1e5  1.1e5  1.3e5   2141    1.0
# mu[52]  1.1e5   261.0  1.2e4  8.2e4  9.8e4  1.1e5  1.1e5  1.3e5   2185    1.0
# mu[53]  1.0e5   269.7  1.2e4  7.7e4  9.6e4  1.0e5  1.1e5  1.3e5   2118    1.0
# mu[54]  1.0e5  269.51  1.3e4  7.9e4  9.6e4  1.0e5  1.1e5  1.3e5   2161    1.0
# mu[55]  1.0e5  274.15  1.3e4  7.8e4  9.5e4  1.0e5  1.1e5  1.3e5   2231    1.0
# mu[56]  1.1e5  289.62  1.3e4  7.9e4  9.7e4  1.1e5  1.1e5  1.3e5   2140    1.0
# mu[57]  1.0e5  293.79  1.4e4  7.4e4  9.4e4  1.0e5  1.1e5  1.3e5   2296    1.0
# mu[58]  1.0e5  308.34  1.5e4  7.1e4  9.3e4  1.0e5  1.1e5  1.3e5   2333    1.0
# mu[59]  1.0e5  339.54  1.6e4  6.6e4  9.0e4  1.0e5  1.1e5  1.3e5   2333    1.0
# s_w    7582.8  295.14 3067.2 3110.4 5366.5 7061.5 9319.4  1.5e4    108   1.03
# s_v     3.9e4   72.84 3989.8  3.2e4  3.6e4  3.8e4  4.1e4  4.7e4   3000    1.0
# lp__    -1183    2.18  22.04  -1225  -1199  -1184  -1168  -1138    102   1.02
#
# Samples were drawn using NUTS at Mon Nov  2 04:39:54 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
fit.plot()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['IPAMincho'] not found. Falling back to DejaVu Sans.

# %%
#結果を抽出
ms = fit.extract() 

#muの事後平均を算出
mu_mean = ms['mu'].mean(axis=0)

#95パーセンタイルを抽出
mu_5 = np.array(pd.DataFrame(ms['mu']).apply(lambda x: np.percentile(x, 5), axis=0))
mu_95 = np.array(pd.DataFrame(ms['mu']).apply(lambda x: np.percentile(x, 95), axis=0))

#x軸
X = df.index

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(X, df['2001位'], label='observed')
# ax.plot(X, mu, label='true trend', c='green')
ax.plot(X, mu_mean, label='predicted trend', c='red')
plt.fill_between(X, mu_5, mu_95, color='red', alpha=0.2)
# plt.legend(loc='upper left', borderaxespad=0, fontsize=15)
plt.show()

# %% [markdown]
# 全然当たっていないが、とりあえず中心あたりは通ってる気がする

# %% [markdown]
# # 残差確認

# %%
from sklearn.metrics import r2_score

# %%
df['predict'] = mu_mean
# 予測とのズレ（差）
df['diff'] = df['2001位'] - df['predict']
df.drop(['1位', '形式', '属性'], axis=1, inplace=True)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 6 threads.

# %%
# 決定係数 (R2)
r2_score(df['2001位'], df['predict'])
# Out:
# 0.29135437900419103

# %%
fig, ax = plt.subplots(1, 1)
ax.scatter(df['2001位'], df['predict'])
ideal_min = min(df['2001位'].min(), df['predict'].min())
ideal_max = max(df['2001位'].max(), df['predict'].max())
ax.plot([ideal_min, ideal_max], [ideal_min, ideal_max], color='r')
plt.show()
